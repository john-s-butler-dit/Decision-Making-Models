# %%
import brian2
brian2.test()
# Out:
# Running tests in /Users/johnbutler/opt/anaconda3/lib/python3.8/site-packages/brian2 for targets numpy, cython (excluding long tests)
# Running Brian version 2.4.2 from '/Users/johnbutler/opt/anaconda3/lib/python3.8/site-packages/brian2'
# Testing codegen-independent code
# Resetting to default preferences
#
# Running doctests
#
# ==================================== ERRORS ====================================
# ___________ ERROR collecting codegen/runtime/GSLweave_rt/__init__.py ___________
# /Users/johnbutler/opt/anaconda3/lib/python3.8/site-packages/brian2/codegen/runtime/GSLweave_rt/__init__.py:1: in <module>
#     from .GSLweave_rt import *
# /Users/johnbutler/opt/anaconda3/lib/python3.8/site-packages/brian2/codegen/runtime/GSLweave_rt/GSLweave_rt.py:18: in <module>
#     from ..weave_rt import WeaveCodeObject
# /Users/johnbutler/opt/anaconda3/lib/python3.8/site-packages/brian2/codegen/runtime/weave_rt/__init__.py:5: in <module>
#     from .weave_rt import *
# ...
